# %%
print(" hola estudiantes")

# %%
"2/10"

# %% [markdown]
# creando variable python

# %%
edad = 18
print(edad+10)

# %%
variable tipo string

# %%
nombre = "JUAN"
print(nombre)
print(type(nombre))

# %% [markdown]
# variable entero

# %%
edad=18
print(edad)
print(type(edad))

# %% [markdown]
# variable tipo decimal

# %%
estatura = 1.70
print(estatura)
print(type(estatura))

# %% [markdown]
# variable tipo booleano

# %%
Es_mayor_de_edad = True
es_menor_de_edad= False
print(Es_mayor_de_edad)
print(es_menor_de_edad)
print(type(Es_mayor_de_edad))
print(type(es_menor_de_edad))

# %%
activo= 1500000
pasivo = 2000000
print(activo)
print(pasivo)
print(activo-pasivo)
print(activo+pasivo)
print(activo/pasivo)
print(activo*pasivo)

print(activo//pasivo)
print(activo%pasivo)
